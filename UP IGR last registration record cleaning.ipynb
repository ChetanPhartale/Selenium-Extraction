# %%
import pandas as pd

# %%
Ayodhya_Sadar_Registration_data = pd.read_excel(r"D:\Data\UP\Ayodhya_Sadar_Registration_data.xlsx")
# Ayodhya_Sadar_Registration_data = pd.read_excel(r"D:\Data\UP\list3.xlsx")

# %%
Ayodhya_Sadar_Registration_data
# Out:
#        Unnamed: 0  series  year  Report_number  \
# 0               0       1  2023              1
# 1               1       1  2023              2
# 2               2       1  2023              3
# 3               3       1  2023              4
# 4               4       1  2023              5
# ...           ...     ...   ...            ...
# 14212       14212       1  2023          14218
# 14213       14213       1  2023          14219
# 14214       14214       1  2023          14220
# 14215       14215       1  2023          14221
# 14216       14216       1  2023          14222
#
#                                           पक्षकार का नाम  \
# 0      \n\n\n\n                                      ...
# 1      \n\n\n\n                                      ...
# 2      \n\n\n\n                                      ...
# 3      \n\n\n\n                                      ...
# 4      \n\n\n\n                                      ...
# ...

# %%
Ayodhya_Sadar_Registration_data = Ayodhya_Sadar_Registration_data.drop(['Unnamed: 0'], axis=1)
Ayodhya_Sadar_Registration_data
# Out:
#        series  year  Report_number  \
# 0           1  2023              1
# 1           1  2023              2
# 2           1  2023              3
# 3           1  2023              4
# 4           1  2023              5
# ...       ...   ...            ...
# 14212       1  2023          14218
# 14213       1  2023          14219
# 14214       1  2023          14220
# 14215       1  2023          14221
# 14216       1  2023          14222
#
#                                           पक्षकार का नाम  \
# 0      \n\n\n\n                                      ...
# 1      \n\n\n\n                                      ...
# 2      \n\n\n\n                                      ...
# 3      \n\n\n\n                                      ...
# 4      \n\n\n\n                                      ...
# ...                                                  ...
# 14212  \n\n\n\n                                      ...
# 14213  \n\n\n\n                                      ...
# ...

# %%
list3 = pd.read_excel(r"D:\Data\UP\UP_Ayodhya_Sadar_1\Sadar_part448 (14223-14228).xlsx")
list3
# Out:
#    Unnamed: 0  series  year  Report_number  \
# 0           0       1  2023          14223
# 1           1       1  2023          14224
# 2           2       1  2023          14225
# 3           3       1  2023          14226
# 4           4       1  2023          14227
# 5           5       1  2023          14228
#
#                                       पक्षकार का नाम  \
# 0  \n\n\n\n                                      ...
# 1  \n\n\n\n                                      ...
# 2  \n\n\n\n                                      ...
# 3  \n\n\n\n                                      ...
# 4  \n\n\n\n                                      ...
# 5  \n\n\n\n                                      ...
#
#                                       पक्षकार का पता  \
# 0  \n                                            ...
# 1  \n                                            ...
# 2  \n                                            ...
# 3  \n                                            ...
# ...

# %%
list3 = list3.drop(['Unnamed: 0'], axis=1)
list3
# Out:
#    series  year  Report_number  \
# 0       1  2023          14223
# 1       1  2023          14224
# 2       1  2023          14225
# 3       1  2023          14226
# 4       1  2023          14227
# 5       1  2023          14228
#
#                                       पक्षकार का नाम  \
# 0  \n\n\n\n                                      ...
# 1  \n\n\n\n                                      ...
# 2  \n\n\n\n                                      ...
# 3  \n\n\n\n                                      ...
# 4  \n\n\n\n                                      ...
# 5  \n\n\n\n                                      ...
#
#                                       पक्षकार का पता  \
# 0  \n                                            ...
# 1  \n                                            ...
# 2  \n                                            ...
# 3  \n                                            ...
# 4  \n                                            ...
# ...

# %%
Ayodhya_Sadar_Registration_data = pd.concat([Ayodhya_Sadar_Registration_data,list3],ignore_index=True)
Ayodhya_Sadar_Registration_data
# Out:
#        series  year  Report_number  \
# 0           1  2023              1
# 1           1  2023              2
# 2           1  2023              3
# 3           1  2023              4
# 4           1  2023              5
# ...       ...   ...            ...
# 14218       1  2023          14224
# 14219       1  2023          14225
# 14220       1  2023          14226
# 14221       1  2023          14227
# 14222       1  2023          14228
#
#                                           पक्षकार का नाम  \
# 0      \n\n\n\n                                      ...
# 1      \n\n\n\n                                      ...
# 2      \n\n\n\n                                      ...
# 3      \n\n\n\n                                      ...
# 4      \n\n\n\n                                      ...
# ...                                                  ...
# 14218  \n\n\n\n                                      ...
# 14219  \n\n\n\n                                      ...
# ...

# %%
Ayodhya_Sadar_Registration_data.columns
# Out:
# Index(['series', 'year', 'Report_number', 'पक्षकार का नाम', 'पक्षकार का पता',
#        'सम्पत्ति का विवरण', 'खसरा /मकान /गाटा संख्या', 'पंजीकरण तिथि',
#        'लेखपत्र का विवरण', 'Registration_date', 'Registration_type', 'col2',
#        'col3', 'col4', 'District', 'SRO'],
#       dtype='object')

# %%
# Ayodhya_Sadar_Registration_data = Ayodhya_Sadar_Registration_data.drop(['Unnamed: 0'], axis=1)
# Shrawasti_Sadar_Registration_data

# %%
Ayodhya_Sadar_Registration_data = Ayodhya_Sadar_Registration_data.drop_duplicates(subset='Report_number', keep="last", ignore_index=True)

# %%
Ayodhya_Sadar_Registration_data
# Out:
#        series  year  Report_number  \
# 0           1  2023              1
# 1           1  2023              2
# 2           1  2023              3
# 3           1  2023              4
# 4           1  2023              5
# ...       ...   ...            ...
# 14218       1  2023          14224
# 14219       1  2023          14225
# 14220       1  2023          14226
# 14221       1  2023          14227
# 14222       1  2023          14228
#
#                                           पक्षकार का नाम  \
# 0      \n\n\n\n                                      ...
# 1      \n\n\n\n                                      ...
# 2      \n\n\n\n                                      ...
# 3      \n\n\n\n                                      ...
# 4      \n\n\n\n                                      ...
# ...                                                  ...
# 14218  \n\n\n\n                                      ...
# 14219  \n\n\n\n                                      ...
# ...

# %%
Ayodhya_Sadar_Registration_data.to_excel("Ayodhya_Sadar_Registration_data.xlsx")
